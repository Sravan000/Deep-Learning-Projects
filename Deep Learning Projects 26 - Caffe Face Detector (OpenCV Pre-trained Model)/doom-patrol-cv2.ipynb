# %% [markdown]
# ![](https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/14f797d9-ce55-4dad-a2e3-966ae51122f0/dczuvrd-d746805a-c1a5-43b7-a052-4f645fc7a3d6.png?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJ1cm46YXBwOiIsImlzcyI6InVybjphcHA6Iiwib2JqIjpbW3sicGF0aCI6IlwvZlwvMTRmNzk3ZDktY2U1NS00ZGFkLWEyZTMtOTY2YWU1MTEyMmYwXC9kY3p1dnJkLWQ3NDY4MDVhLWMxYTUtNDNiNy1hMDUyLTRmNjQ1ZmM3YTNkNi5wbmcifV1dLCJhdWQiOlsidXJuOnNlcnZpY2U6ZmlsZS5kb3dubG9hZCJdfQ._rJFeK7MtbnMcIYQrr68BB3ky8oix3dYbqnBPPIZ5_k)https://www.deviantart.com/drdarkdoom/art/Doom-Patrol-TV-Series-2019-785821513

# %% [markdown]
# #Larry Trainor :I hate that word. “Hero.” It’s dangerous. A title other people hang on you and you’re supposed to carry it around.
#
# #That's why Doom Patrol members are Super Zeroes.
#
# Doom Patrol is an American web television series developed by Jeremy Carver for DC Universe. Based on the DC Comics superhero team of the same name, the series features Jane (Diane Guerrero), Rita Farr (April Bowlby), Vic Stone (Joivan Wade), Larry Trainor (Matt Bomer / Matthew Zuk), Cliff Steele (Brendan Fraser / Riley Shanahan), and the Chief (Timothy Dalton) as the members of the eponymous Doom Patrol. Although Bowlby, Bomer, and Fraser reprise their roles from the DC Universe series Titans, the two shows are set in separate continuities.https://en.wikipedia.org/wiki/Doom_Patrol_(TV_series)

# %%
from fastai.vision import *
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %%
folder_path = Path('../input/cusersmarilonedriveimagensdoomjpg')

# %%
image_path = get_image_files(folder_path)[0]

image_path
# Out:
# PosixPath('../input/cusersmarilonedriveimagensdoomjpg/Doom_Patrol_(Volume_1)_logo.JPG.jpg')

# %%
image = cv2.imread(str(image_path))

image.shape
# Out:
# (143, 296, 3)

# %% [markdown]
# ![](https://prodimage.images-bn.com/pimages/2940153308654_p0_v1_s550x406.jpg)barnesandnoble.com

# %%
h, w = image.shape[:2]

# %%
plt.figure(figsize=(w/30, h/30))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
arch = '../input/caffe-face-detector-opencv-pretrained-model/architecture.txt'
weights = '../input/caffe-face-detector-opencv-pretrained-model/weights.caffemodel'

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)
# Out:
# <img src="data:image/jpeg;base64,..." width="400" height="400"/>

# %% [markdown]
# multiversitycomics.com - Danny the Street (who writes its thoughts).

# %%
neural_net = cv2.dnn.readNetFromCaffe(arch, weights)

# %%
blob = cv2.dnn.blobFromImage(
    image=cv2.resize(image, (299, 299)), # Resize the image to 299px by 299px.
    scalefactor=1.0, # Set the scaling factor.
    size=(299, 299), # Specify the spatial size of the image.
    mean=(103.93, 116.77, 123.68) # Normalize by subtracting the per-channel means of ImageNet images (which were used to train the pre-trained model).
)

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRnTiBj5Y1_gbbEbTKKTzOVFb-yvNk9AzfFLA&usqp=CAU)deviantart.com

# %%
neural_net.setInput(blob)
detections = neural_net.forward()

# %% [markdown]
# <iframe width="871" height="490" src="https://www.youtube.com/embed/oV7tG2AJXJ8" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# #Flex Mentallo Make Doom Patrol Orgasm | Doom Patrol S01xE14

# %%
type(detections)
# Out:
# numpy.ndarray

# %%
detections.shape
# Out:
# (1, 1, 200, 7)

# %% [markdown]
# ![](https://i.redd.it/w70mtiqa0p521.jpg)https://www.reddit.com/r/TitansTV/comments/a8e6j0/love_the_doom_patrol_hope_we_get_more_stuff_like/

# %%
threshold = 0.5

# %%
for i in range(0, detections.shape[2]):
    confidence = detections[0, 0, i, 2]
    if confidence > threshold:
        box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
        startX, startY, endX, endY = box.astype('int')
        text = '{:.2f}%'.format(confidence * 100)
        textY = startY - 10 if startY - 10 > 10 else startY + 10 # Ensure that the text won't go off-image.
        cv2.rectangle(
            img=image, 
            pt1=(startX, startY), # Vertex of the rectangle.
            pt2=(endX, endY), # Vertex of the rectangle opposite to `pt1`.
            color=(255, 0, 0),
            thickness=2
        )
        cv2.putText(
            img=image, 
            text=text, 
            org=(startX, textY), # Bottom-left corner of the text string.
            fontFace=cv2.FONT_HERSHEY_SIMPLEX, 
            fontScale=0.5, 
            color=(255, 0, 0),
            thickness=2
        )

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQk9hAkHXQOH0l3MuoNwq6hiqH5vfXwtAJZAg&usqp=CAU)magicalquote.com

# %% [markdown]
# #Mr. Nobody : Ready for a story about superheroes? Ugh. More TV superheroes, just what the world needs. Be honest, have you hung #yourself yet? Or, what if I told you this was actually a story about super-zeroes? Losers, achingly pathetic meta-human goose eggs. #How about it? Ready to feel better about your own miserable lives for the next hour or so? Follow me.

# %% [markdown]
# #Take a look at the image along with the bounding box and the confidence.
# As there isn't any face to detect (just a LOGO). No Detection at all.

# %%
plt.figure(figsize=(w/30, h/30))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
